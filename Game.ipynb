# %%
print("У місті Драконове бродив легендарний лицар на ім'я Сір Артур, \nякий був відомий своєю незламною відвагою та величезним серцем.\nПоширювалася легенда про те, що прекрасна принцеса Ельза була ув'язнена в замку дракона Скеледзуба, і Сір Артур вирушив на неймовірну подорож, щоб звільнити її та покласти край жахливим діянням дракона.")

right_answer = 0

name = str(input("Введіть імʼя користувача"))
selection = int(input(f"Хлопчик на ім'я {name} потрапив у казковий світ математики,\nу якому тільки вирішенням виразів можна досягти виграшу\n"
                      "1. Вирішувати складні задачі для легшого отримання першого місця на зманагннях\n2.Вирішувати легкі задачі для отримання другого або 3"))


if selection == 1:  # 1
    print("У Оксани було 20 марок із серії «Мистецтво» і 7 марок із серії «Звірі».\n"
          "5 марок вона подарувала подружці. Скільки марок лишилось у Оксани?")
    answer = int(input("Відповідь: "))
    if answer == 22:  # 2
        print("Молодець, правильно, ось і ще 1 задача\n"
              "У книжці 14 сторінок. Вранці Віра прочитала 9 сторінок, а ввечері ще 3 сторінки. Скільки сторінок лишилось прочитати?")
        right_answer = + 3
        answer = int(input("Відповіль: "))
        if answer == 2:  # 3
            print("Молодець, правильно, ось і ще 1 задача\n"
                  "Володя зібрав 68 марок. 13 марок він подарував Петру, 2 марки наклеїв на поштову листівку. Скільки марок у нього залишилось?")
            right_answer = + 3
            answer = int(input("Відповідь: "))
            if answer == 53:  # 4
                print("Молодець, це була остання задача")
                right_answer = + 3
            elif answer != 53:  # 4
                print("Не правильно, це була остання задача")
        elif answer != 2:  # 3
            print("Ні, бали не зараховано. Тримай ще задачку\n"
                  "В одному бідоні 30 л молока, а в другому – 12 л. З 10 л молока зварили кашу. Скільки літрів молока залишилось?")
            answer = int(input("Відповідь: "))
            if answer == 32:  # 4
                right_answer = + 3
                print("Молодець правильно, це була остання задачка")
    elif answer != 22:  # 2
        print("Погано, давай іншу задачку\n"
              "В одній вазі 20 квіток, у другій – 9, а в третій – стільки ж, скільки в першій та другій разом. Скільки квіток у третій вазі?")
        answer = int(input("Відповідь: "))
        if answer == 29:  # 3
            right_answer = + 3
            print("Розу-у-у-умник, правильно\n"
                  "Ще одна задача\n"
                  "Книжку, в якій 21 сторінка, Василько прочитав за 3 дні. Першого дня він прочитав 5 сторінок, другого – 7.\n"
                  "Скільки сторінок прочитав Василько третього дня?")
            answer = int(input("Відповідь: "))
            if answer == 9:  # 4
                print("Молодець, правильно, це була остання задача")
                right_answer = + 3
            elif answer != 9:  # 4
                print("Не правильно, це була остання задача")
        elif answer != 29:  # 3
            print("НІ, неправильно, спробуй цю задачу\n"
                  "Якщо у коробці було 18 маршмелоу, а Макс взяв 8 і Ірина взяла 3, скільки маршмелоу залишилося в коробці?")
            answer = int(input("Відповідь: "))
            if answer == 6:  # 4
                right_answer = + 3
                print("Молодець правильно, це була остання задачка")
            elif answer != 6:  # 4
                print("Неправильно, це була остання задачка")


elif selection == 2:  # 1
    print("Ось твоя перша задачка\n"
          "У Олі було 7 прапорців. Подрузі вона подарувала 3 прапорця. Скільки прапорців залишилось у дівчинки?")
    answer = int(input("Відповідь: "))
    if answer == 4:  # 2
        right_answer = + 2
        print("Правильна відповідь, ось тобі нова задачка\n"
              "На гілці сиділо 10 горобців. Улетіло 8 птахів. Скільки горобців залишилось?")
        answer = int(input("Відповідь: "))
        if answer == 2:  # 3
            right_answer = + 2
            print("Молодець бали зараховано, ось наступна задачка\n"
                  "В автобусі сиділо 5 пасажирів, зайшло ще 3 . Скільки пасажирів стало в автобусі?")
            answer = int(input("Відповідь: "))
            if answer == 8:  # 4
                right_answer = + 2
                print("Правильно це була остання задача")
            elif answer != 8:  # 4
                print("Погано, це була остання задачка")
        elif answer != 2:  # 3
            print("Думай, це не правильно, ось тобі ще задачка\n"
                  "Якщо у Марійки було 14 соковитих апельсинів, і вона подарувала 6 з них своєму другу, скільки апельсинів залишилося у Марійки?")
            answer = int(input("Відповідь: "))
            if answer == 8:  # 4
                right_answer = + 2
                print("Молодець, це була отсання задачка")
            elif answer != 8:  # 4
                print("Погано, це була остання задачка")
    elif answer != 4:  # 2
        print("Неправильно, ось тобі ще задача\n"
              "У бідоні було 10л молока. За обідом випили 3л. Скільки літрів молока залишилось в бідоні?")
        answer = int(input("Відповідь: "))
        if answer == 7:  # 3
            right_answer = + 2
            print("Розумник, ось тобі ще задача\n"
                  "В класі було 15 учнів, а потім прийшло ще 6. Скільки всього учнів в класі тепер?")
            answer = int(input("Відповідь: "))
            if answer == 21:  # 4
                right_answer = + 2
                print("Молодець, це була остання задачка")
            elif answer != 21:  # 4
                print("Неправильно, це була остання задачка")
        elif answer != 7:  # 3
            print("Неправильно, думай над ще 1 задачкою\n"
                  "У Макса було 10 монеток, і він додав ще 9 монеток до своєї колекції. Скільки всього монеток у Макса тепер?")
            answer = int(input("Відповідь: "))
            if answer == 19:  # 4
                print("Молодець, це була остання задачка")
                right_answer = + 2
            elif answer != 19:  # 4
                print("Неправильно, це була остання задачка")

print(right_answer)
if right_answer >= 4:
    print("Молодець, ти переможець")
else:
    print("Вчися")
